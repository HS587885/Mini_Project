# %% [markdown]
# # DataConcat

# %% [markdown]
# ## 2012~2022 전체 데이터 합치기

# %% [markdown]
# ### Water data

# %%
from glob import glob
import pandas as pd

# %%
water = sorted(glob('water_data/*.csv'))
water
# Out:
# ['water_data/data_2012.csv',
#  'water_data/data_2013.csv',
#  'water_data/data_2014.csv',
#  'water_data/data_2015.csv',
#  'water_data/data_2016.csv',
#  'water_data/data_2017.csv',
#  'water_data/data_2018.csv',
#  'water_data/data_2019.csv',
#  'water_data/data_2020.csv',
#  'water_data/data_2021.csv',
#  'water_data/data_2022.csv']

# %%
df1 = pd.read_csv(water[0],index_col=0)

for i in water[1:]:
    temp = pd.read_csv(i,index_col=0)
    df1 = pd.concat([df1,temp],axis=0)
df1.shape
# Out:
# (276336, 14)

# %%
df1
# Out:
#                      swl     inf     sfw   ecpc  tototf  tide_level  \
# ymdhm
# 2012-05-01 00:00  24.800  555.00  219.07  24.93  555.00       445.0
# 2012-05-01 00:10  24.794  464.60  218.86  25.15  562.90       449.0
# 2012-05-01 00:20  24.789  478.10  218.69  25.31  576.40       451.0
# 2012-05-01 00:30  24.789  464.80  218.69  25.31  563.10       452.0
# 2012-05-01 00:40  24.789  478.10  218.69  25.31  576.40       450.0
# ...                  ...     ...     ...    ...     ...         ...
# 2022-07-18 23:10  25.040  259.23  212.86  31.14  259.23       510.0
# 2022-07-18 23:20  25.040  260.46  212.86  31.14  260.46       492.0
# 2022-07-18 23:30  25.040  259.37  212.86  31.14  259.37       475.0
# 2022-07-18 23:40  25.040  259.13  212.86  31.14  259.13       458.0
# 2022-07-18 23:50  25.040  258.16  212.86  31.14  258.16       442.0
#
#                   wl_1018662  fw_1018662  wl_1018680  fw_1018680  wl_1018683  \
# ymdhm
# 2012-05-01 00:00       310.7      469.05       300.2         0.0       290.0
# 2012-05-01 00:10       314.7      498.00       300.2         0.0       290.0
# 2012-05-01 00:20       313.7      490.68       301.2         0.0       290.0
# 2012-05-01 00:30       311.7      476.21       301.2         0.0       290.0
# 2012-05-01 00:40       311.7      476.21       301.2         0.0       291.0
# ...                      ...         ...         ...         ...         ...
# 2022-07-18 23:10         0.0      319.84         0.0         NaN         0.0
# 2022-07-18 23:20         0.0      314.01         0.0         NaN         0.0
# 2022-07-18 23:30         0.0      387.55         0.0         NaN         0.0
# 2022-07-18 23:40         0.0      454.91         0.0         NaN         0.0
# 2022-07-18 23:50         0.0      582.21         0.0         NaN         0.0
#
#                   fw_1018683  wl_1019630  fw_1019630
# ymdhm
# 2012-05-01 00:00      729.80       275.3      540.18
# 2012-05-01 00:10      731.48       275.3      540.18
# 2012-05-01 00:20      726.42       275.3      540.18
# 2012-05-01 00:30      726.42       276.3      552.17
# 2012-05-01 00:40      707.17       277.3      564.29
# ...                      ...         ...         ...
# 2022-07-18 23:10     -456.41         0.0      974.40
# 2022-07-18 23:20     -717.30         0.0     1006.88
# 2022-07-18 23:30     -843.37         0.0     1039.90
# 2022-07-18 23:40    -1023.37         0.0     1073.46
# 2022-07-18 23:50    -1049.44         0.0     1090.45
#
# [276336 rows x 14 columns]

# %%
df1.to_csv('combined_water_data(2012-2022).csv')

# %% [markdown]
# ### Rain data

# %%
rain = sorted(glob('rf_data/*.csv'))
rain
# Out:
# ['rf_data/rf_2012.csv',
#  'rf_data/rf_2013.csv',
#  'rf_data/rf_2014.csv',
#  'rf_data/rf_2015.csv',
#  'rf_data/rf_2016.csv',
#  'rf_data/rf_2017.csv',
#  'rf_data/rf_2018.csv',
#  'rf_data/rf_2019.csv',
#  'rf_data/rf_2020.csv',
#  'rf_data/rf_2021.csv',
#  'rf_data/rf_2022.csv']

# %%
df2 = pd.read_csv(rain[0],index_col=0)

for i in rain[1:]:
    temp = pd.read_csv(i,index_col=0)
    df2 = pd.concat([df2,temp],axis=0)
df2.shape
# Out:
# (276336, 3)

# %%
df2
# Out:
#                   rf_10184100  rf_10184110  rf_10184140
# ymdhm
# 2012-05-01 00:00          0.0          0.0          0.0
# 2012-05-01 00:10          0.0          0.0          0.0
# 2012-05-01 00:20          0.0          0.0          0.0
# 2012-05-01 00:30          0.0          0.0          0.0
# 2012-05-01 00:40          0.0          0.0          0.0
# ...                       ...          ...          ...
# 2022-07-18 23:10          0.0          0.0          0.0
# 2022-07-18 23:20          0.0          0.0          0.0
# 2022-07-18 23:30          0.0          0.0          0.0
# 2022-07-18 23:40          0.0          0.0          0.0
# 2022-07-18 23:50          0.0          0.0          0.0
#
# [276336 rows x 3 columns]

# %%
df2.to_csv('combined_rainfall_data(2012-2022).csv')

# %% [markdown]
# ### Data concat

# %%
combine = pd.concat([df1,df2],axis=1)
combine
# Out:
#                      swl     inf     sfw   ecpc  tototf  tide_level  \
# ymdhm
# 2012-05-01 00:00  24.800  555.00  219.07  24.93  555.00       445.0
# 2012-05-01 00:10  24.794  464.60  218.86  25.15  562.90       449.0
# 2012-05-01 00:20  24.789  478.10  218.69  25.31  576.40       451.0
# 2012-05-01 00:30  24.789  464.80  218.69  25.31  563.10       452.0
# 2012-05-01 00:40  24.789  478.10  218.69  25.31  576.40       450.0
# ...                  ...     ...     ...    ...     ...         ...
# 2022-07-18 23:10  25.040  259.23  212.86  31.14  259.23       510.0
# 2022-07-18 23:20  25.040  260.46  212.86  31.14  260.46       492.0
# 2022-07-18 23:30  25.040  259.37  212.86  31.14  259.37       475.0
# 2022-07-18 23:40  25.040  259.13  212.86  31.14  259.13       458.0
# 2022-07-18 23:50  25.040  258.16  212.86  31.14  258.16       442.0
#
#                   wl_1018662  fw_1018662  wl_1018680  fw_1018680  wl_1018683  \
# ymdhm
# 2012-05-01 00:00       310.7      469.05       300.2         0.0       290.0
# 2012-05-01 00:10       314.7      498.00       300.2         0.0       290.0
# 2012-05-01 00:20       313.7      490.68       301.2         0.0       290.0
# 2012-05-01 00:30       311.7      476.21       301.2         0.0       290.0
# 2012-05-01 00:40       311.7      476.21       301.2         0.0       291.0
# ...                      ...         ...         ...         ...         ...
# 2022-07-18 23:10         0.0      319.84         0.0         NaN         0.0
# 2022-07-18 23:20         0.0      314.01         0.0         NaN         0.0
# 2022-07-18 23:30         0.0      387.55         0.0         NaN         0.0
# 2022-07-18 23:40         0.0      454.91         0.0         NaN         0.0
# 2022-07-18 23:50         0.0      582.21         0.0         NaN         0.0
#
#                   fw_1018683  wl_1019630  fw_1019630  rf_10184100  \
# ymdhm
# 2012-05-01 00:00      729.80       275.3      540.18          0.0
# 2012-05-01 00:10      731.48       275.3      540.18          0.0
# 2012-05-01 00:20      726.42       275.3      540.18          0.0
# 2012-05-01 00:30      726.42       276.3      552.17          0.0
# 2012-05-01 00:40      707.17       277.3      564.29          0.0
# ...                      ...         ...         ...          ...
# 2022-07-18 23:10     -456.41         0.0      974.40          0.0
# 2022-07-18 23:20     -717.30         0.0     1006.88          0.0
# 2022-07-18 23:30     -843.37         0.0     1039.90          0.0
# 2022-07-18 23:40    -1023.37         0.0     1073.46          0.0
# 2022-07-18 23:50    -1049.44         0.0     1090.45          0.0
#
#                   rf_10184110  rf_10184140
# ymdhm
# 2012-05-01 00:00          0.0          0.0
# 2012-05-01 00:10          0.0          0.0
# 2012-05-01 00:20          0.0          0.0
# 2012-05-01 00:30          0.0          0.0
# 2012-05-01 00:40          0.0          0.0
# ...                       ...          ...
# 2022-07-18 23:10          0.0          0.0
# 2022-07-18 23:20          0.0          0.0
# 2022-07-18 23:30          0.0          0.0
# 2022-07-18 23:40          0.0          0.0
# 2022-07-18 23:50          0.0          0.0
#
# [276336 rows x 17 columns]

# %%
combine.to_csv('combined_data(2012-2022).csv')

# %% [markdown]
# # Module 불러오기

# %%
import numpy as np
import pandas as pd
import os

from tqdm import tqdm

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# 관련 라이브러리 임포트
import matplotlib.font_manager as fm

#  한글글꼴로 변경
plt.rc('font', family='NanumMyeongjo') # For Windows

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
matplotlib.rcParams['axes.unicode_minus'] = False

# 그래프 기본 크기 설정
plt.rcParams['figure.figsize'] = [10, 6]

# %%
pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in /home/as9786/.local/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.8/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.8/dist-packages (from statsmodels) (1.2.4)
# Requirement already satisfied: numpy>=1.17 in /home/as9786/.local/lib/python3.8/site-packages (from statsmodels) (1.19.5)
# Requirement already satisfied: patsy>=0.5.2 in /home/as9786/.local/lib/python3.8/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: packaging>=21.3 in /home/as9786/.local/lib/python3.8/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=21.3->statsmodels) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->statsmodels) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25->statsmodels) (2021.1)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# WARNING: You are using pip version 21.3.1; however, version 22.2.2 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import mse, rmse, aic
from statsmodels.tsa.stattools import grangercausalitytests

from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 결측치 처리

# %% [markdown]
# **[결측치 처리]**
# - 시계열데이터이므로 결측치를 평균값 보다는 보간법으로 채워주는 것이 좋음 <br> (그래야 t-1시점과 t+1시점의 값 사이에 smooth 하게 이어줄 수 있음) <br>
# (특히, 우리나라 강수량은 여름 며칠에만 집중적이어서 평균값이 전체 특성을 반영하지 못할 수 있음)
# - 공용량(ecpc) 이상치는 저수량(sfw) 결측치, 이상치를 먼저 채운 뒤에 '244.0 - sfw' 값으로 대체
#
# **[이상치 탐색]**
# - 총방류량(tototf), 유입량(inf) 이상치
#   - 2013-09-16, 2018-06-08, 2018-07-05 : 두 변수 보간법 등으로 변경해주기
#   - 2020-08-22 18:50:00 : 방류량0으로 변경해주기
#   - 2020-08-22 19:00:00 : 유입량 bfill로 변경해주기

# %% [markdown]
# ## Module

# %%
filepath='combined_train_test_filled.csv'

# %%
#인덱스type을 datetime형으로 변환하여 데이터프레임 생성
df=pd.read_csv(filepath, index_col='ymdhm', parse_dates=['ymdhm'])
df.index
# Out:
# DatetimeIndex(['2012-05-01 00:00:00', '2012-05-01 00:10:00',
#                '2012-05-01 00:20:00', '2012-05-01 00:30:00',
#                '2012-05-01 00:40:00', '2012-05-01 00:50:00',
#                '2012-05-01 01:00:00', '2012-05-01 01:10:00',
#                '2012-05-01 01:20:00', '2012-05-01 01:30:00',
#                ...
#                '2022-07-18 22:20:00', '2022-07-18 22:30:00',
#                '2022-07-18 22:40:00', '2022-07-18 22:50:00',
#                '2022-07-18 23:00:00', '2022-07-18 23:10:00',
#                '2022-07-18 23:20:00', '2022-07-18 23:30:00',
#                '2022-07-18 23:40:00', '2022-07-18 23:50:00'],
#               dtype='datetime64[ns]', name='ymdhm', length=276336, freq=None)

# %% [markdown]
# ## 결측치 처리
# - 보간법으로 결측치 채우기
# - Pandas.Series.Interpolate

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 276336 entries, 2012-05-01 00:00:00 to 2022-07-18 23:50:00
# Data columns (total 17 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   swl          275593 non-null  float64
#  1   inf          275593 non-null  float64
#  2   sfw          275593 non-null  float64
#  3   ecpc         275593 non-null  float64
#  4   tototf       275593 non-null  float64
#  5   tide_level   271409 non-null  float64
#  6   wl_1018662   276277 non-null  float64
#  7   fw_1018662   259956 non-null  float64
#  8   wl_1018680   276277 non-null  float64
#  9   fw_1018680   79487 non-null   float64
#  10  wl_1018683   276277 non-null  float64
#  11  fw_1018683   275057 non-null  float64
#  12  wl_1019630   276277 non-null  float64
#  13  fw_1019630   276277 non-null  float64
#  14  rf_10184100  276336 non-null  float64
#  15  rf_10184110  276336 non-null  float64
#  16  rf_10184140  276336 non-null  float64
# dtypes: float64(17)
# memory usage: 37.9 MB

# %%
df.isnull().sum()
# Out:
# swl               743
# inf               743
# sfw               743
# ecpc              743
# tototf            743
# tide_level       4927
# wl_1018662         59
# fw_1018662      16380
# wl_1018680         59
# fw_1018680     196849
# wl_1018683         59
# fw_1018683       1279
# wl_1019630         59
# fw_1019630         59
# rf_10184100         0
# rf_10184110         0
# rf_10184140         0
# dtype: int64

# %%
df1 = df.copy()

# %%
df2 = df.interpolate(method='linear')

# %%
df.interpolate(method='linear', inplace=True)

# %%
df2.isnull().sum()
# Out:
# swl            0
# inf            0
# sfw            0
# ecpc           0
# tototf         0
# tide_level     0
# wl_1018662     0
# fw_1018662     0
# wl_1018680     0
# fw_1018680     0
# wl_1018683     0
# fw_1018683     0
# wl_1019630     0
# fw_1019630     0
# rf_10184100    0
# rf_10184110    0
# rf_10184140    0
# dtype: int64

# %%
df_swl_swf_ecpc=df1[['swl','sfw','ecpc']]
df_swl_swf_ecpc
# Out:
#                         swl     sfw   ecpc
# ymdhm
# 2012-05-01 00:00:00  24.800  219.07  24.93
# 2012-05-01 00:10:00  24.794  218.86  25.15
# 2012-05-01 00:20:00  24.789  218.69  25.31
# 2012-05-01 00:30:00  24.789  218.69  25.31
# 2012-05-01 00:40:00  24.789  218.69  25.31
# ...                     ...     ...    ...
# 2022-07-18 23:10:00  25.040  212.86  31.14
# 2022-07-18 23:20:00  25.040  212.86  31.14
# 2022-07-18 23:30:00  25.040  212.86  31.14
# 2022-07-18 23:40:00  25.040  212.86  31.14
# 2022-07-18 23:50:00  25.040  212.86  31.14
#
# [276336 rows x 3 columns]

# %%
df_swl_swf_ecpc[df_swl_swf_ecpc['swl']==0]
# Out:
#                      swl   sfw    ecpc
# ymdhm
# 2012-07-02 21:00:00  0.0  0.00  244.00
# 2012-07-02 22:00:00  0.0  0.00  244.00
# 2012-07-02 23:00:00  0.0  0.00  244.00
# 2012-07-03 00:00:00  0.0  0.00  244.00
# 2012-07-03 01:00:00  0.0  0.00  244.00
# ...                  ...   ...     ...
# 2013-07-12 04:00:00  0.0  0.00  244.00
# 2013-07-12 05:00:00  0.0  0.00  244.00
# 2013-07-12 06:00:00  0.0  0.00  244.00
# 2013-07-12 07:00:00  0.0  0.00  244.00
# 2018-07-05 16:40:00  0.0 -0.01  244.01
#
# [83 rows x 3 columns]

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3, 1, figsize=(10,10))
ax1.plot(df_swl_swf_ecpc['swl'],'r')
ax2.plot(df_swl_swf_ecpc['sfw'],'g')
ax3.plot(df_swl_swf_ecpc['ecpc'],'b')
plt.show()

# %% [markdown]
# ## 이상치 처리

# %% [markdown]
# ### swl(현재수위), sfw(현재저수량), ecpc(공용량)
# 저수량(sfw) + 공용량(ecpc) = 총저수용량 = 244.0 이므로
# - 현재수위(swl)과 저수량(sfw)만 보간법으로 이상치 변환해주고
# - 공용량(ecpc)는 '244.0-sfw' 값으로 변환하기

# %%
# swl, sfw 이상치 -> 결측치로 바꿔주기
dt_range=df['swl'][df['swl']==0].index

for i in range(len(dt_range)):
  df.loc[dt_range[i]]['swl']=np.nan

for i in range(len(dt_range)):
  df.loc[dt_range[i]]['sfw']=np.nan

# %%
df[['swl','sfw']].isnull().sum()
# Out:
# swl    83
# sfw    83
# dtype: int64

# %%
# swl, sfw 결측치 -> 보간법으로 채우기
df['swl'].interpolate(method='linear', inplace=True)
df['sfw'].interpolate(method='linear', inplace=True)

# %%
df[['swl','sfw']].isnull().sum()
# Out:
# swl    0
# sfw    0
# dtype: int64

# %%
df['swl'][df['swl']==0]
# Out:
# Series([], Name: swl, dtype: float64)

# %%
df['sfw'][df['sfw']==0]
# Out:
# Series([], Name: sfw, dtype: float64)

# %% [markdown]
# ecpc 이상치: ecpc = 244-sfw로 바꾸기

# %%
df['ecpc'][df['ecpc']>240]
# Out:
# ymdhm
# 2012-07-02 21:00:00    244.00
# 2012-07-02 22:00:00    244.00
# 2012-07-02 23:00:00    244.00
# 2012-07-03 00:00:00    244.00
# 2012-07-03 01:00:00    244.00
#                         ...
# 2013-07-12 04:00:00    244.00
# 2013-07-12 05:00:00    244.00
# 2013-07-12 06:00:00    244.00
# 2013-07-12 07:00:00    244.00
# 2018-07-05 16:40:00    244.01
# Name: ecpc, Length: 83, dtype: float64

# %%
for i in range(len(dt_range)):
  df.loc[dt_range[i]]['ecpc']=244.0-df.loc[dt_range[i]]['sfw']

# %%
df[['ecpc']].isnull().sum()
# Out:
# ecpc    0
# dtype: int64

# %%
df['ecpc'][df['ecpc']>240] # 이상치 없음
# Out:
# Series([], Name: ecpc, dtype: float64)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(3, 1, figsize=(15,10))
ax1.plot(df['swl'],'r')
ax2.plot(df['sfw'],'g')
ax3.plot(df['ecpc'],'b')
plt.show()

# %% [markdown]
# ### 총방류량(tototf), 유입량(inf)
# - 2013-09-16, 2018-06-08, 2018-07-05 : 두 변수 보간법 등으로 변경해주기
# - 2020-08-22 18:50:00 : 방류량0으로 변경해주기
# - 2020-08-22 19:00:00 : 방류량0,유입량 bfill로 변경해주기

# %%
df_swf_tototf_inf=df1[['sfw','tototf','inf']]
df_swf_tototf_inf
# Out:
#                         sfw  tototf     inf
# ymdhm
# 2012-05-01 00:00:00  219.07  555.00  555.00
# 2012-05-01 00:10:00  218.86  562.90  464.60
# 2012-05-01 00:20:00  218.69  576.40  478.10
# 2012-05-01 00:30:00  218.69  563.10  464.80
# 2012-05-01 00:40:00  218.69  576.40  478.10
# ...                     ...     ...     ...
# 2022-07-18 23:10:00  212.86  259.23  259.23
# 2022-07-18 23:20:00  212.86  260.46  260.46
# 2022-07-18 23:30:00  212.86  259.37  259.37
# 2022-07-18 23:40:00  212.86  259.13  259.13
# 2022-07-18 23:50:00  212.86  258.16  258.16
#
# [276336 rows x 3 columns]

# %%
# 저수량변화량 열 추가
df_swf_tototf_inf['sfw_t-1']=df_swf_tototf_inf['sfw'].shift(1)
df_swf_tototf_inf['sfw_change']=df_swf_tototf_inf['sfw']-df_swf_tototf_inf['sfw_t-1']
df_swf_tototf_inf
# Out:
#                         sfw  tototf     inf  sfw_t-1  sfw_change
# ymdhm
# 2012-05-01 00:00:00  219.07  555.00  555.00      NaN         NaN
# 2012-05-01 00:10:00  218.86  562.90  464.60   219.07       -0.21
# 2012-05-01 00:20:00  218.69  576.40  478.10   218.86       -0.17
# 2012-05-01 00:30:00  218.69  563.10  464.80   218.69        0.00
# 2012-05-01 00:40:00  218.69  576.40  478.10   218.69        0.00
# ...                     ...     ...     ...      ...         ...
# 2022-07-18 23:10:00  212.86  259.23  259.23   212.86        0.00
# 2022-07-18 23:20:00  212.86  260.46  260.46   212.86        0.00
# 2022-07-18 23:30:00  212.86  259.37  259.37   212.86        0.00
# 2022-07-18 23:40:00  212.86  259.13  259.13   212.86        0.00
# 2022-07-18 23:50:00  212.86  258.16  258.16   212.86        0.00
#
# [276336 rows x 5 columns]

# %%
df_swf_tototf_inf[df_swf_tototf_inf['tototf']<0]
# Out:
#                         sfw  tototf    inf  sfw_t-1  sfw_change
# ymdhm
# 2013-09-16 04:40:00  236.45  -203.8 -303.8   236.45        0.00
# 2018-06-08 16:00:00  212.86  -122.0  -21.0   212.86        0.00
# 2018-07-05 16:40:00   -0.01  -990.0 -990.0   212.14     -212.15
# 2020-08-22 18:50:00  206.01  -404.0    0.0   206.01        0.00
# 2020-08-22 19:00:00  206.73  -222.0    0.0   206.01        0.72

# %%
# 2013-09-16 => 총방류량, 유입량 이상치임 => 보간법으로 smooting 해주기
plt.figure(figsize=(15,7))
ax1 = plt.subplot(111)
ax2 = ax1.twinx()
a, =  ax1.plot(df_swf_tototf_inf.loc['2013-09-16']['tototf'], color='red', label="tototf(총방류량)")
b, =  ax2.plot(df_swf_tototf_inf.loc['2013-09-16']['sfw'], color='green', label="swf(현재저수량)")
ax1.axhline(y=0, color='black', linewidth=1)

p = [a, b]
ax1.legend(p, [p_.get_label() for p_ in p], loc='lower left')
plt.title('총방류량(좌)과 현재저수량(우)')
plt.show()

# %%
plt.figure(figsize=(15,7))
ax1 = plt.subplot(111)
ax2 = ax1.twinx()
a, =  ax1.plot(df_swf_tototf_inf.loc['2013-09-16']['tototf'], color='red', label="tototf(총방류량)")
b, =  ax2.plot(df_swf_tototf_inf.loc['2013-09-16']['inf'], color='orange', label="inf(유입량)")
ax1.axhline(y=0, color='black',linewidth=1)

p = [a, b]
ax1.legend(p, [p_.get_label() for p_ in p], loc='lower left')
plt.title('총방류량(좌)과 유입량(우)')
plt.show()

# %% [markdown]
# 2018-06-08 => 총방류량, 유입량 이상치임 => 보간법으로 smooting 해주기

# %%
plt.figure(figsize=(15,7))
ax1 = plt.subplot(111)
ax2 = ax1.twinx()
a, =  ax1.plot(df_swf_tototf_inf.loc['2018-06-08']['tototf'], color='red', label="tototf(총방류량)")
b, =  ax2.plot(df_swf_tototf_inf.loc['2018-06-08']['sfw'], color='green', label="swf(현재저수량)")
ax1.axhline(y=0, color='black', linewidth=1)

p = [a, b]
ax1.legend(p, [p_.get_label() for p_ in p], loc='lower left')
plt.title('총방류량(좌)과 현재저수량(우)')
plt.show()

# %%
plt.figure(figsize=(15,7))
ax1 = plt.subplot(111)
ax2 = ax1.twinx()
a, =  ax1.plot(df_swf_tototf_inf.loc['2018-06-08']['inf'], color='orange', label="inf(유입량)")
b, =  ax2.plot(df_swf_tototf_inf.loc['2018-06-08']['sfw_change'], color='blue', label="swf_change(저수량 변화량)")
ax1.axhline(y=0, color='black',linewidth=1)

p = [a, b]
ax1.legend(p, [p_.get_label() for p_ in p], loc='lower left')
plt.title('유입량(좌)과 저수량변화량(우)')
plt.show()

# %%
# 이상치 -> 결측치로 바꿔주기
dt_list=['2013-09-16 04:40:00', '2018-06-08 16:00:00', '2018-07-05 16:40:00']
for i in range(len(dt_list)):
  df.loc[dt_list[i]]['tototf']=np.nan
  df.loc[dt_list[i]]['inf']=np.nan

# %%
print(df[['tototf']].isnull().sum())
print(df[['inf']].isnull().sum())
# Out:
# tototf    3
# dtype: int64
# inf    3
# dtype: int64

# %%
df['tototf'].interpolate(method='linear', inplace=True)
df['inf'].interpolate(method='linear', inplace=True)

# %%
print(df[['tototf']].isnull().sum())
print(df[['inf']].isnull().sum())
# Out:
# tototf    0
# dtype: int64
# inf    0
# dtype: int64

# %%
df.loc['2020-08-22 18:30':'2020-08-22 19:30',['sfw','tototf','inf']]
# Out:
#                         sfw  tototf    inf
# ymdhm
# 2020-08-22 18:30:00  206.01   701.0  701.0
# 2020-08-22 18:40:00  206.01   708.0  708.0
# 2020-08-22 18:50:00  206.01  -404.0    0.0
# 2020-08-22 19:00:00  206.73  -222.0    0.0
# 2020-08-22 19:10:00  207.08     0.0  297.0
# 2020-08-22 19:20:00  206.73     0.0  198.0
# 2020-08-22 19:30:00  206.01     0.0    0.0

# %%
df.loc['2020-08-22 18:50:00']['tototf']=0.0
df.loc['2020-08-22 19:00:00']['tototf']=0.0
df.loc['2020-08-22 19:00:00']['inf']=df.loc['2020-08-22 19:10:00']['inf']

# %%
df.loc['2020-08-22 18:30':'2020-08-22 19:30',['sfw','tototf','inf']]
# Out:
#                         sfw  tototf    inf
# ymdhm
# 2020-08-22 18:30:00  206.01   701.0  701.0
# 2020-08-22 18:40:00  206.01   708.0  708.0
# 2020-08-22 18:50:00  206.01     0.0    0.0
# 2020-08-22 19:00:00  206.73     0.0  297.0
# 2020-08-22 19:10:00  207.08     0.0  297.0
# 2020-08-22 19:20:00  206.73     0.0  198.0
# 2020-08-22 19:30:00  206.01     0.0    0.0

# %%
df.describe()
# Out:
#                  swl            inf            sfw           ecpc  \
# count  276336.000000  276336.000000  276336.000000  276336.000000
# mean       25.079251     548.548083     219.425047      24.575537
# std         0.146126    1110.978412       9.912109       9.911699
# min        23.993000    -807.500000     176.380000       2.150000
# 25%        24.980000     127.417500     211.770000      14.670000
# 50%        25.100000     249.570000     217.630000      26.370000
# 75%        25.190000     530.000000     229.330000      32.230000
# max        25.449000   25991.500000     241.850000      67.620000
#
#               tototf     tide_level     wl_1018662     fw_1018662  \
# count  276336.000000  276336.000000  276336.000000  276336.000000
# mean      542.037573     345.631700     329.232797     746.826551
# std      1104.317316     174.250734      76.559900    1077.388189
# min         0.000000      39.000000     259.700000     243.290000
# 25%       132.000000     192.000000     287.700000     319.840000
# 50%       174.980000     324.000000     307.000000     441.000000
# 75%       505.000000     487.000000     342.700000     725.690000
# max     25791.500000     842.000000    1287.700000    9405.640000
#
#           wl_1018680  fw_1018680     wl_1018683     fw_1018683     wl_1019630  \
# count  276336.000000    276336.0  276336.000000  276336.000000  276336.000000
# mean      316.071760         0.0     312.590404     600.970021     299.979812
# std        67.495669         0.0      63.883452    1376.848129      51.442783
# min       246.200000         0.0     247.000000   -3522.710000     241.300000
# 25%       278.200000         0.0     275.000000     205.082500     267.300000
# 50%       297.200000         0.0     295.000000     355.980000     286.300000
# 75%       330.200000         0.0     328.000000     709.710000     316.300000
# max      1146.200000         0.0    1080.000000   25289.170000     843.300000
#
#           fw_1019630    rf_10184100    rf_10184110    rf_10184140
# count  276336.000000  276336.000000  276336.000000  276336.000000
# mean     1056.807758       0.034074       0.038265       0.035985
# std      1428.279212       0.338607       0.370553       0.360769
# min       212.040000       0.000000       0.000000       0.000000
# 25%       449.120000       0.000000       0.000000       0.000000
# 50%       679.420000       0.000000       0.000000       0.000000
# 75%      1142.220000       0.000000       0.000000       0.000000
# max     29854.120000      24.000000      21.000000      24.000000

# %% [markdown]
# ## 데이터 csv로 저장

# %%
df.to_csv('combined_train_test_filled_cleansed.csv')

# %% [markdown]
# # Data 불러오기

# %%
# 전처리한 데이터 불러오기
df=pd.read_csv('combined_train_test_filled_cleansed.csv', index_col='ymdhm', parse_dates=['ymdhm'])
df
# Out:
#                         swl     inf     sfw   ecpc  tototf  tide_level  \
# ymdhm
# 2012-05-01 00:00:00  24.800  555.00  219.07  24.93  555.00       445.0
# 2012-05-01 00:10:00  24.794  464.60  218.86  25.15  562.90       449.0
# 2012-05-01 00:20:00  24.789  478.10  218.69  25.31  576.40       451.0
# 2012-05-01 00:30:00  24.789  464.80  218.69  25.31  563.10       452.0
# 2012-05-01 00:40:00  24.789  478.10  218.69  25.31  576.40       450.0
# ...                     ...     ...     ...    ...     ...         ...
# 2022-07-18 23:10:00  25.040  259.23  212.86  31.14  259.23       510.0
# 2022-07-18 23:20:00  25.040  260.46  212.86  31.14  260.46       492.0
# 2022-07-18 23:30:00  25.040  259.37  212.86  31.14  259.37       475.0
# 2022-07-18 23:40:00  25.040  259.13  212.86  31.14  259.13       458.0
# 2022-07-18 23:50:00  25.040  258.16  212.86  31.14  258.16       442.0
#
#                      wl_1018662  fw_1018662  wl_1018680  fw_1018680  \
# ymdhm
# 2012-05-01 00:00:00       310.7      469.05       300.2         0.0
# 2012-05-01 00:10:00       314.7      498.00       300.2         0.0
# 2012-05-01 00:20:00       313.7      490.68       301.2         0.0
# 2012-05-01 00:30:00       311.7      476.21       301.2         0.0
# 2012-05-01 00:40:00       311.7      476.21       301.2         0.0
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00       288.0      319.84       295.0         0.0
# 2022-07-18 23:20:00       287.0      314.01       303.0         0.0
# 2022-07-18 23:30:00       299.0      387.55       307.0         0.0
# 2022-07-18 23:40:00       309.0      454.91       311.0         0.0
# 2022-07-18 23:50:00       326.0      582.21       314.0         0.0
#
#                      wl_1018683  fw_1018683  wl_1019630  fw_1019630  \
# ymdhm
# 2012-05-01 00:00:00       290.0      729.80       275.3      540.18
# 2012-05-01 00:10:00       290.0      731.48       275.3      540.18
# 2012-05-01 00:20:00       290.0      726.42       275.3      540.18
# 2012-05-01 00:30:00       290.0      726.42       276.3      552.17
# 2012-05-01 00:40:00       291.0      707.17       277.3      564.29
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00       299.0     -456.41       306.0      974.40
# 2022-07-18 23:20:00       304.0     -717.30       308.0     1006.88
# 2022-07-18 23:30:00       309.0     -843.37       310.0     1039.90
# 2022-07-18 23:40:00       314.0    -1023.37       312.0     1073.46
# 2022-07-18 23:50:00       317.0    -1049.44       313.0     1090.45
#
#                      rf_10184100  rf_10184110  rf_10184140
# ymdhm
# 2012-05-01 00:00:00          0.0          0.0          0.0
# 2012-05-01 00:10:00          0.0          0.0          0.0
# 2012-05-01 00:20:00          0.0          0.0          0.0
# 2012-05-01 00:30:00          0.0          0.0          0.0
# 2012-05-01 00:40:00          0.0          0.0          0.0
# ...                          ...          ...          ...
# 2022-07-18 23:10:00          0.0          0.0          0.0
# 2022-07-18 23:20:00          0.0          0.0          0.0
# 2022-07-18 23:30:00          0.0          0.0          0.0
# 2022-07-18 23:40:00          0.0          0.0          0.0
# 2022-07-18 23:50:00          0.0          0.0          0.0
#
# [276336 rows x 17 columns]

# %%
# fw_1018680는 원래 없는 자료이므로 삭제
df.drop('fw_1018680', axis=1, inplace=True)

# %%
df.describe()
# Out:
#                  swl            inf            sfw           ecpc  \
# count  276336.000000  276336.000000  276336.000000  276336.000000
# mean       25.079251     548.548083     219.425047      24.575537
# std         0.146126    1110.978412       9.912109       9.911699
# min        23.993000    -807.500000     176.380000       2.150000
# 25%        24.980000     127.417500     211.770000      14.670000
# 50%        25.100000     249.570000     217.630000      26.370000
# 75%        25.190000     530.000000     229.330000      32.230000
# max        25.449000   25991.500000     241.850000      67.620000
#
#               tototf     tide_level     wl_1018662     fw_1018662  \
# count  276336.000000  276336.000000  276336.000000  276336.000000
# mean      542.037573     345.631700     329.232797     746.826551
# std      1104.317316     174.250734      76.559900    1077.388189
# min         0.000000      39.000000     259.700000     243.290000
# 25%       132.000000     192.000000     287.700000     319.840000
# 50%       174.980000     324.000000     307.000000     441.000000
# 75%       505.000000     487.000000     342.700000     725.690000
# max     25791.500000     842.000000    1287.700000    9405.640000
#
#           wl_1018680     wl_1018683     fw_1018683     wl_1019630  \
# count  276336.000000  276336.000000  276336.000000  276336.000000
# mean      316.071760     312.590404     600.970021     299.979812
# std        67.495669      63.883452    1376.848129      51.442783
# min       246.200000     247.000000   -3522.710000     241.300000
# 25%       278.200000     275.000000     205.082500     267.300000
# 50%       297.200000     295.000000     355.980000     286.300000
# 75%       330.200000     328.000000     709.710000     316.300000
# max      1146.200000    1080.000000   25289.170000     843.300000
#
#           fw_1019630    rf_10184100    rf_10184110    rf_10184140
# count  276336.000000  276336.000000  276336.000000  276336.000000
# mean     1056.807758       0.034074       0.038265       0.035985
# std      1428.279212       0.338607       0.370553       0.360769
# min       212.040000       0.000000       0.000000       0.000000
# 25%       449.120000       0.000000       0.000000       0.000000
# 50%       679.420000       0.000000       0.000000       0.000000
# 75%      1142.220000       0.000000       0.000000       0.000000
# max     29854.120000      24.000000      21.000000      24.000000

# %%
# 원본 data 분포

y_cols=['wl_1018662', 'wl_1018680', 'wl_1018683', 'wl_1019630']
x_cols=df.drop(y_cols,axis=1).columns

fig,axes=plt.subplots(4,3, figsize=(20,15))
for i in tqdm(range(4)):
  for j in range(3):
    sns.histplot(data=df, x=x_cols[i*3+j], kde=True, ax=axes[i,j])
plt.show()
# Out:
# 100%|██████████| 4/4 [00:11<00:00,  2.95s/it]

# %% [markdown]
# # 전처리(Scaling)

# %% [markdown]
# ## Log-Scaling

# %% [markdown]
# ### Scaling

# %%
y_cols=['wl_1018662', 'wl_1018680', 'wl_1018683', 'wl_1019630']
x_cols=df.drop(y_cols,axis=1).columns

df_log=pd.DataFrame.copy(df)
df_log=df_log.drop(y_cols, axis=1)

# 전체 상용로그변환 (x-min(x)+1) 변환
for i in range(len(x_cols)):
    df_log[x_cols[i]]=np.log10(df_log[x_cols[i]]-min(df_log[x_cols[i]])+1)

# %%
# 변환한 분포 그래프  확인
fig,axes=plt.subplots(4,3, figsize=(20,15))
for i in tqdm(range(4)):
  for j in range(3):
    sns.histplot(data=df_log, x=x_cols[i*3+j], kde=True, ax=axes[i,j])
plt.show()
# Out:
# 100%|██████████| 4/4 [00:10<00:00,  2.54s/it]

# %% [markdown]
# # 변수 적합성 판단

# %% [markdown]
# ## Granger causality

# %%
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False, maxlag=5):

    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df.columns:
        for r in df.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)

            df.loc[r, c] = min_p_value
    df.columns = [var + '_x' for var in variables]
    df.index = [var + '_y' for var in variables]
    return df

# %%
df_gc=df[y_cols].merge(df_log, on='ymdhm')
df_gc.head()
# Out:
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630       swl  \
# ymdhm
# 2012-05-01 00:00:00       310.7       300.2       290.0       275.3  0.256958
# 2012-05-01 00:10:00       314.7       300.2       290.0       275.3  0.255514
# 2012-05-01 00:20:00       313.7       301.2       290.0       275.3  0.254306
# 2012-05-01 00:30:00       311.7       301.2       290.0       276.3  0.254306
# 2012-05-01 00:40:00       311.7       301.2       291.0       277.3  0.254306
#
#                           inf       sfw      ecpc    tototf  tide_level  \
# ymdhm
# 2012-05-01 00:00:00  3.134655  1.640382  1.376212  2.745075    2.609594
# 2012-05-01 00:10:00  3.104863  1.638290  1.380211  2.751202    2.613842
# 2012-05-01 00:20:00  3.109444  1.636588  1.383097  2.761477    2.615950
# 2012-05-01 00:30:00  3.104931  1.636588  1.383097  2.751356    2.617000
# 2012-05-01 00:40:00  3.109444  1.636588  1.383097  2.761477    2.614897
#
#                      fw_1018662  fw_1018683  fw_1019630  rf_10184100  \
# ymdhm
# 2012-05-01 00:00:00    2.355566    3.628747    2.517381          0.0
# 2012-05-01 00:10:00    2.407748    3.628919    2.517381          0.0
# 2012-05-01 00:20:00    2.395134    3.628402    2.517381          0.0
# 2012-05-01 00:30:00    2.369067    3.628402    2.532920          0.0
# 2012-05-01 00:40:00    2.369067    3.626431    2.548082          0.0
#
#                      rf_10184110  rf_10184140
# ymdhm
# 2012-05-01 00:00:00          0.0          0.0
# 2012-05-01 00:10:00          0.0          0.0
# 2012-05-01 00:20:00          0.0          0.0
# 2012-05-01 00:30:00          0.0          0.0
# 2012-05-01 00:40:00          0.0          0.0

# %%
grangers_causation_matrix(df_gc, variables=df_gc.columns)
# Out:
#                wl_1018662_x  wl_1018680_x  wl_1018683_x  wl_1019630_x  swl_x  \
# wl_1018662_y            1.0           0.0           0.0        0.0000    0.0
# wl_1018680_y            0.0           1.0           0.0        0.0000    0.0
# wl_1018683_y            0.0           0.0           1.0        0.0000    0.0
# wl_1019630_y            0.0           0.0           0.0        1.0000    0.0
# swl_y                   0.0           0.0           0.0        0.0000    1.0
# inf_y                   0.0           0.0           0.0        0.0000    0.0
# sfw_y                   0.0           0.0           0.0        0.0036    0.0
# ecpc_y                  0.0           0.0           0.0        0.0022    0.0
# tototf_y                0.0           0.0           0.0        0.0000    0.0
# tide_level_y            0.0           0.0           0.0        0.0000    0.0
# fw_1018662_y            0.0           0.0           0.0        0.0000    0.0
# fw_1018683_y            0.0           0.0           0.0        0.0000    0.0
# fw_1019630_y            0.0           0.0           0.0        0.0000    0.0
# rf_10184100_y           0.0           0.0           0.0        0.0000    0.0
# rf_10184110_y           0.0           0.0           0.0        0.0000    0.0
# rf_10184140_y           0.0           0.0           0.0        0.0000    0.0
#
#                inf_x   sfw_x  ecpc_x  tototf_x  tide_level_x  fw_1018662_x  \
# wl_1018662_y     0.0  0.0000  0.0000       0.0        0.0000        0.0000
# wl_1018680_y     0.0  0.0000  0.0000       0.0        0.0000        0.0000
# wl_1018683_y     0.0  0.0000  0.0000       0.0        0.0000        0.0000
# wl_1019630_y     0.0  0.0000  0.0000       0.0        0.0000        0.0000
# swl_y            0.0  0.0000  0.0000       0.0        0.1536        0.0000
# inf_y            1.0  0.0000  0.0000       0.0        0.0000        0.0000
# sfw_y            0.0  1.0000  0.0000       0.0        0.5105        0.0250
# ecpc_y           0.0  0.0000  1.0000       0.0        0.7850        0.0009
# tototf_y         0.0  0.0000  0.0000       1.0        0.0003        0.0000
# tide_level_y     0.0  0.2148  0.9054       0.0        1.0000        0.0000
# fw_1018662_y     0.0  0.0002  0.0915       0.0        0.0000        1.0000
# fw_1018683_y     0.0  0.0000  0.0000       0.0        0.0000        0.0000
# fw_1019630_y     0.0  0.0000  0.0000       0.0        0.0000        0.0000
# rf_10184100_y    0.0  0.0000  0.0000       0.0        0.0001        0.0000
# rf_10184110_y    0.0  0.0000  0.0000       0.0        0.0011        0.0000
# rf_10184140_y    0.0  0.0000  0.0000       0.0        0.0055        0.0000
#
#                fw_1018683_x  fw_1019630_x  rf_10184100_x  rf_10184110_x  \
# wl_1018662_y         0.0000        0.0000         0.0000         0.0000
# wl_1018680_y         0.0000        0.0000         0.0000         0.0000
# wl_1018683_y         0.0000        0.0000         0.0000         0.0000
# wl_1019630_y         0.0000        0.0000         0.0000         0.0000
# swl_y                0.0000        0.0000         0.0291         0.0171
# inf_y                0.0000        0.0000         0.0000         0.0000
# sfw_y                0.0056        0.0015         0.0084         0.0018
# ecpc_y               0.0287        0.0007         0.0000         0.0020
# tototf_y             0.0000        0.0000         0.0000         0.0000
# tide_level_y         0.0000        0.0000         0.2128         0.0101
# fw_1018662_y         0.0000        0.0000         0.0000         0.0000
# fw_1018683_y         1.0000        0.0000         0.0000         0.0000
# fw_1019630_y         0.0000        1.0000         0.0000         0.0000
# rf_10184100_y        0.0000        0.0000         1.0000         0.0000
# rf_10184110_y        0.0000        0.0000         0.0000         1.0000
# rf_10184140_y        0.0000        0.0000         0.0000         0.0000
#
#                rf_10184140_x
# wl_1018662_y          0.0000
# wl_1018680_y          0.0000
# wl_1018683_y          0.0000
# wl_1019630_y          0.0000
# swl_y                 0.0120
# inf_y                 0.0000
# sfw_y                 0.0000
# ecpc_y                0.0001
# tototf_y              0.0000
# tide_level_y          0.0802
# fw_1018662_y          0.0000
# fw_1018683_y          0.0000
# fw_1019630_y          0.0000
# rf_10184100_y         0.0000
# rf_10184110_y         0.0000
# rf_10184140_y         1.0000

# %% [markdown]
# ## 다중공선성(VIF)
# - X변수들 간 비교

# %%
def feature_engineering_XbyVIF(X_train):
    vif = pd.DataFrame()
    vif['VIF_Factor'] = [variance_inflation_factor(X_train.values, i)
                         for i in range(X_train.shape[1])]
    vif['Feature'] = X_train.columns
    return vif

# %%
vif=feature_engineering_XbyVIF(df_log)
print(vif)
# Out:
#      VIF_Factor      Feature
# 0    312.689641          swl
# 1   1431.420095          inf
# 2   1168.802655          sfw
# 3     95.222016         ecpc
# 4    140.225381       tototf
# 5     65.448356   tide_level
# 6     46.018933   fw_1018662
# 7   1619.445958   fw_1018683
# 8    191.786899   fw_1019630
# 9      1.441508  rf_10184100
# 10     1.466831  rf_10184110
# 11     1.597302  rf_10184140

# %%
vif=feature_engineering_XbyVIF(df_log.drop('inf',axis=1))
print(vif)
# Out:
#      VIF_Factor      Feature
# 0    312.642865          swl
# 1   1153.559528          sfw
# 2     93.192692         ecpc
# 3     74.878437       tototf
# 4     64.588002   tide_level
# 5     45.211044   fw_1018662
# 6   1181.224681   fw_1018683
# 7    180.631163   fw_1019630
# 8      1.441315  rf_10184100
# 9      1.466396  rf_10184110
# 10     1.597194  rf_10184140

# %%
vif=feature_engineering_XbyVIF(df_log.drop(['inf','sfw'],axis=1))
print(vif)
# Out:
#    VIF_Factor      Feature
# 0  155.288922          swl
# 1   52.170467         ecpc
# 2   71.402666       tototf
# 3   60.048087   tide_level
# 4   45.106617   fw_1018662
# 5  462.069564   fw_1018683
# 6  179.735972   fw_1019630
# 7    1.441314  rf_10184100
# 8    1.466273  rf_10184110
# 9    1.597139  rf_10184140

# %%
vif = feature_engineering_XbyVIF(df_log.drop(['inf', 'sfw', 'fw_1018683'], axis=1))
print(vif)
# Out:
#    VIF_Factor      Feature
# 0   47.739621          swl
# 1   29.778153         ecpc
# 2   52.613550       tototf
# 3   58.499421   tide_level
# 4   44.985571   fw_1018662
# 5  178.029813   fw_1019630
# 6    1.440984  rf_10184100
# 7    1.465443  rf_10184110
# 8    1.596778  rf_10184140

# %% [markdown]
# ## Train-Test 분리

# %%
df_scaled=pd.concat([df_log,df[y_cols]], axis=1)
df_train=df_scaled.loc[:'2022-05']
df_tt=df_scaled.loc['2022':]
df_tt
# Out:
#                           swl       inf       sfw      ecpc    tototf  \
# ymdhm
# 2022-05-01 00:00:00  0.343802  3.189732  1.636989  1.382377  2.098159
# 2022-05-01 00:10:00  0.343802  2.969872  1.636989  1.382377  2.098575
# 2022-05-01 00:20:00  0.343802  2.969742  1.636989  1.382377  2.097604
# 2022-05-01 00:30:00  0.343802  2.969812  1.636989  1.382377  2.098124
# 2022-05-01 00:40:00  0.341830  2.907680  1.633266  1.388989  2.098367
# ...                       ...       ...       ...       ...       ...
# 2022-07-18 23:10:00  0.311118  3.028461  1.573800  1.476976  2.415357
# 2022-07-18 23:20:00  0.311118  3.028961  1.573800  1.476976  2.417405
# 2022-07-18 23:30:00  0.311118  3.028518  1.573800  1.476976  2.415591
# 2022-07-18 23:40:00  0.311118  3.028421  1.573800  1.476976  2.415190
# 2022-07-18 23:50:00  0.311118  3.028026  1.573800  1.476976  2.413568
#
#                      tide_level  fw_1018662  fw_1018683  fw_1019630  \
# ymdhm
# 2022-05-01 00:00:00    1.633468    1.979321    3.547000    2.415040
# 2022-05-01 00:10:00    1.531479    2.006038    3.564530    2.356580
# 2022-05-01 00:20:00    1.414973    1.979321    3.574717    2.314141
# 2022-05-01 00:30:00    1.301030    1.951143    3.582793    2.291702
# 2022-05-01 00:40:00    1.301030    1.889582    3.587008    2.314141
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00    2.673942    1.889582    3.486756    2.882729
# 2022-07-18 23:20:00    2.657056    1.855640    3.448151    2.900826
# 2022-07-18 23:30:00    2.640481    2.162146    3.428190    2.918481
# 2022-07-18 23:40:00    2.623249    2.327604    3.397999    2.935719
# 2022-07-18 23:50:00    2.606381    2.531377    3.393447    2.944191
#
#                      rf_10184100  rf_10184110  rf_10184140  wl_1018662  \
# ymdhm
# 2022-05-01 00:00:00          0.0          0.0          0.0       290.7
# 2022-05-01 00:10:00          0.0          0.0          0.0       291.7
# 2022-05-01 00:20:00          0.0          0.0          0.0       290.7
# 2022-05-01 00:30:00          0.0          0.0          0.0       289.7
# 2022-05-01 00:40:00          0.0          0.0          0.0       287.7
# ...                          ...          ...          ...         ...
# 2022-07-18 23:10:00          0.0          0.0          0.0       288.0
# 2022-07-18 23:20:00          0.0          0.0          0.0       287.0
# 2022-07-18 23:30:00          0.0          0.0          0.0       299.0
# 2022-07-18 23:40:00          0.0          0.0          0.0       309.0
# 2022-07-18 23:50:00          0.0          0.0          0.0       326.0
#
#                      wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-05-01 00:00:00       284.2       279.0       269.3
# 2022-05-01 00:10:00       284.2       279.0       266.3
# 2022-05-01 00:20:00       284.2       279.0       264.3
# 2022-05-01 00:30:00       284.2       279.0       263.3
# 2022-05-01 00:40:00       284.2       279.0       264.3
# ...                         ...         ...         ...
# 2022-07-18 23:10:00       295.0       299.0       306.0
# 2022-07-18 23:20:00       303.0       304.0       308.0
# 2022-07-18 23:30:00       307.0       309.0       310.0
# 2022-07-18 23:40:00       311.0       314.0       312.0
# 2022-07-18 23:50:00       314.0       317.0       313.0
#
# [11376 rows x 16 columns]

# %%
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
#df_train 각 열에 ADF Test 
for name, column in df_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "swl"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -15.1588
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "inf"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -11.3961
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "sfw"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.7912
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "ecpc"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -8.6369
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "tototf"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -12.6037
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "tide_level"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -47.0974
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "fw_1018662"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -16.6708
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "fw_1018683"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -12.2951
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "fw_1019630"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -14.856
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "rf_10184100"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -43.2997
#  No. Lags Chosen       = 85
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "rf_10184110"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -42.0967
#  No. Lags Chosen       = 84
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "rf_10184140"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -42.4326
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "wl_1018662"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.9651
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "wl_1018680"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.9082
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "wl_1018683"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -13.83
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "wl_1019630"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -12.844
#  No. Lags Chosen       = 87
#  Critical value 1%     = -3.43
#  Critical value 5%     = -2.862
#  Critical value 10%    = -2.567
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# ## 최적 하이퍼파라미터 p 찾기
# - AIC를 제일 작게 하는 p
# - step을 20부터 하여 전체적인 p의 범위를 찾고 그 후 step의 값을 작게 하여 최적의 p 값을 찾음

# %%
# grid-search - step = 20
r_min=60
r_max=200
step=20

model=VAR(df_train) # 학습데이터
results_aic=[]
for p in tqdm(range(r_min,r_max+1,step)):
  results=model.fit(p)
  results_aic.append(results.aic)

# order p와 AIC 시각화
sns.set()
plt.plot(list(np.arange(r_min,r_max+1,step)), results_aic)
plt.xlabel("Order")
plt.ylabel("AIC")
plt.show()

# AIC를 최소로 만드는 p
min_aic=min(results_aic)
p=r_min+step*results_aic.index(min_aic)
print(f'=> {r_min}~{r_max} 범위에서 {step} 간격으로 확인한 결과 : "p={p}"에서 AIC 최소')
# Out:
# 100%|██████████| 8/8 [11:07<00:00, 83.41s/it]
# => 60~200 범위에서 20 간격으로 확인한 결과 : "p=200"에서 AIC 최소

# %%
# grid-search - step 10
r_min=150
r_max=170
step=1

model=VAR(df_train) # 학습데이터
results_aic=[]
for p in tqdm(range(r_min,r_max+1,step)):
  results=model.fit(p)
  results_aic.append(results.aic)

# order p와 AIC 시각화
sns.set()
plt.plot(list(np.arange(r_min,r_max+1,step)), results_aic)
plt.xlabel("Order")
plt.ylabel("AIC")
plt.show()

# AIC를 최소로 만드는 p
min_aic=min(results_aic)
p=r_min+step*results_aic.index(min_aic)
print(f'=> {r_min}~{r_max} 범위에서 {step} 간격으로 확인한 결과 : "p={p}"에서 AIC 최소')
# Out:
# 100%|██████████| 21/21 [38:07<00:00, 108.93s/it]
# => 150~170 범위에서 1 간격으로 확인한 결과 : "p=170"에서 AIC 최소

# %% [markdown]
# => AIC가 완만해지기 시작하는 158~163 구간을 최적 p로 계산해보기

# %%
# grid-search - step = 10
r_min=200
r_max=250
step=10

model=VAR(df_train) # 학습데이터
results_aic=[]
for p in tqdm(range(r_min,r_max+1,step)):
  results=model.fit(p)
  results_aic.append(results.aic)

# order p와 AIC 시각화
sns.set()
plt.plot(list(np.arange(r_min,r_max+1,step)), results_aic)
plt.xlabel("Order")
plt.ylabel("AIC")
plt.show()

# AIC를 최소로 만드는 p
min_aic=min(results_aic)
p=r_min+step*results_aic.index(min_aic)
print(f'=> {r_min}~{r_max} 범위에서 {step} 간격으로 확인한 결과 : "p={p}"에서 AIC 최소')
# Out:
# 100%|██████████| 6/6 [19:40<00:00, 196.76s/it]
# => 200~250 범위에서 10 간격으로 확인한 결과 : "p=230"에서 AIC 최소

# %%
# grid-search - step = 1
r_min=225
r_max=235
step=1

model=VAR(df_train) # 학습데이터
results_aic=[]
for p in tqdm(range(r_min,r_max+1,step)):
  results=model.fit(p)
  results_aic.append(results.aic)

# order p와 AIC 시각화
sns.set()
plt.plot(list(np.arange(r_min,r_max+1,step)), results_aic)
plt.xlabel("Order")
plt.ylabel("AIC")
plt.show()

# AIC를 최소로 만드는 p
min_aic=min(results_aic)
p=r_min+step*results_aic.index(min_aic)
print(f'=> {r_min}~{r_max} 범위에서 {step} 간격으로 확인한 결과 : "p={p}"에서 AIC 최소')
# Out:
# 100%|██████████| 11/11 [37:38<00:00, 205.29s/it]
# => 225~235 범위에서 1 간격으로 확인한 결과 : "p=232"에서 AIC 최소

# %% [markdown]
# # Model

# %%
df_forecast=pd.DataFrame(index=df_tt.index, columns=df_tt.columns)
df_forecast
# Out:
#                      swl  inf  sfw ecpc tototf tide_level fw_1018662  \
# ymdhm
# 2022-05-01 00:00:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# ...                  ...  ...  ...  ...    ...        ...        ...
# 2022-07-18 23:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:50:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
#
#                     fw_1018683 fw_1019630 rf_10184100 rf_10184110 rf_10184140  \
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:40:00        NaN        NaN         NaN         NaN         NaN
# ...                        ...        ...         ...         ...         ...
# 2022-07-18 23:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:40:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:50:00        NaN        NaN         NaN         NaN         NaN
#
#                     wl_1018662 wl_1018680 wl_1018683 wl_1019630
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:10:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:20:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:30:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:40:00        NaN        NaN        NaN        NaN
# ...                        ...        ...        ...        ...
# 2022-07-18 23:10:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:20:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:30:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:40:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:50:00        NaN        NaN        NaN        NaN
#
# [11376 rows x 16 columns]

# %%
def get_fc_ys(lag, df_train, df_tt, df_fc):
    # 모델 학습
    lag=lag
    var=VAR(df_train)
    fitted_var=var.fit(lag)
    for i in tqdm(range(6912)):
      # df_tt에서 예측하려는 시간 직전 lag개 데이터 가져오기
      forecast_input=df_tt.iloc[:4464+i,:].values[-lag:] # 4463행(2022-05-31 23:50:00)
      # 바로 다음 step 1개 예측
      fc=fitted_var.forecast(y=forecast_input, steps=1)
      # df_fc에 예측한 wl 결과값 추가하기
      y_cols=['wl_1018662','wl_1018680','wl_1018683','wl_1019630']
      for name in y_cols:
        col_idx=list(df_fc.columns).index(name)
        df_fc.iloc[4464+i,col_idx]=fc[0][col_idx]
    return df_fc

# %% [markdown]
# ## VAR(232)

# %%
df_forecast232=get_fc_ys(232,df_train,df_tt,df_forecast)
df_forecast232=df_forecast232.loc['2022-06':,y_cols]
df_forecast232
# Out:
# 100%|██████████| 6912/6912 [00:06<00:00, 1035.11it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.881067  277.357497  274.755918  269.417796
# 2022-06-01 00:10:00  280.965182   276.09842  273.344968  267.905346
# 2022-06-01 00:20:00  282.963533  276.668954  273.371601  264.923645
# 2022-06-01 00:30:00  285.735841  277.498578  273.749826  261.724296
# 2022-06-01 00:40:00  286.074258  278.092361  273.938219  258.757841
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.717848  293.855113  297.631806  306.482227
# 2022-07-18 23:20:00  290.402725  302.650977   305.30352   307.89898
# 2022-07-18 23:30:00   295.93029  307.061065  307.808883   310.37599
# 2022-07-18 23:40:00  310.771316  311.819821  312.804292   311.53597
# 2022-07-18 23:50:00  321.814646  316.177708  316.869133  312.211123
#
# [6912 rows x 4 columns]

# %% [markdown]
# ## inf, sfw 제외 모델

# %%
# 필요없는 변수 제거
df_train2=df_train.drop(['inf','sfw'], axis=1)
df_tt2=df_tt.drop(['inf','sfw'], axis=1)
df_forecast2=df_forecast.drop(['inf','sfw'], axis=1)

# %%
df_forecast232=get_fc_ys(232,df_train2,df_tt2,df_forecast2)
df_forecast232=df_forecast232.loc['2022-06':,y_cols]
df_forecast232
# Out:
# 100%|██████████| 6912/6912 [00:07<00:00, 954.38it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.786825    277.4177  274.769228   269.50725
# 2022-06-01 00:10:00  280.999447  276.208293  273.530506  267.643645
# 2022-06-01 00:20:00  282.949552  276.616435  273.370686  264.988745
# 2022-06-01 00:30:00  285.414505  277.475162  273.678069  261.556142
# 2022-06-01 00:40:00  286.147097  278.020174  273.932783  258.834942
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.636036    293.7353  297.690609  306.397955
# 2022-07-18 23:20:00  290.227495  302.530986  305.091021  308.171015
# 2022-07-18 23:30:00  295.900694  307.236131  307.898054  310.212295
# 2022-07-18 23:40:00   310.76332  311.737974  312.767172  311.396866
# 2022-07-18 23:50:00  321.905665  316.311362  316.998116  312.409982
#
# [6912 rows x 4 columns]

# %%
df_forecast232.to_csv('VAR_log.csv')

# %% [markdown]
# # 추가 Scaling

# %% [markdown]
# ## MinMax Scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_train = df_log.loc[:'2022-05-31 23:50:00',list(x_cols)]
X_test = df_log.loc['2022-06-01 00:00:00':,list(x_cols)]
Y = df.loc[:,y_cols]
# scaling
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_scaled = np.concatenate([X_train_scaled,X_test_scaled])

df_mm = pd.DataFrame(X_scaled,columns=list(x_cols),index=df.index)
df_mm.shape
# Out:
# (276336, 12)

# %%
df_scaled=pd.concat([df_mm,df[y_cols]], axis=1)
df_train=df_scaled.loc[:'2022-05']
df_tt=df_scaled.loc['2022':]
df_tt
# Out:
#                           swl       inf       sfw      ecpc    tototf  \
# ymdhm
# 2022-05-01 00:00:00  0.881029  0.720333  0.898149  0.758454  0.475612
# 2022-05-01 00:10:00  0.881029  0.670682  0.898149  0.758454  0.475706
# 2022-05-01 00:20:00  0.881029  0.670653  0.898149  0.758454  0.475486
# 2022-05-01 00:30:00  0.881029  0.670669  0.898149  0.758454  0.475604
# 2022-05-01 00:40:00  0.875974  0.656638  0.896106  0.762081  0.475659
# ...                       ...       ...       ...       ...       ...
# 2022-07-18 23:10:00  0.797271  0.683914  0.863479  0.810356  0.547515
# 2022-07-18 23:20:00  0.797271  0.684026  0.863479  0.810356  0.547979
# 2022-07-18 23:30:00  0.797271  0.683926  0.863479  0.810356  0.547568
# 2022-07-18 23:40:00  0.797271  0.683904  0.863479  0.810356  0.547477
# 2022-07-18 23:50:00  0.797271  0.683815  0.863479  0.810356  0.547109
#
#                      tide_level  fw_1018662  fw_1018683  fw_1019630  \
# ymdhm
# 2022-05-01 00:00:00    0.562246    0.499569    0.795365    0.540045
# 2022-05-01 00:10:00    0.527141    0.506313    0.799296    0.526972
# 2022-05-01 00:20:00    0.487039    0.499569    0.801580    0.517482
# 2022-05-01 00:30:00    0.447819    0.492457    0.803391    0.512464
# 2022-05-01 00:40:00    0.447819    0.476920    0.804336    0.517482
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00    0.920381    0.476920    0.781856    0.644629
# 2022-07-18 23:20:00    0.914569    0.468353    0.773200    0.648675
# 2022-07-18 23:30:00    0.908864    0.545713    0.768724    0.652623
# 2022-07-18 23:40:00    0.902932    0.587474    0.761954    0.656478
# 2022-07-18 23:50:00    0.897126    0.638905    0.760933    0.658373
#
#                      rf_10184100  rf_10184110  rf_10184140  wl_1018662  \
# ymdhm
# 2022-05-01 00:00:00          0.0          0.0          0.0       290.7
# 2022-05-01 00:10:00          0.0          0.0          0.0       291.7
# 2022-05-01 00:20:00          0.0          0.0          0.0       290.7
# 2022-05-01 00:30:00          0.0          0.0          0.0       289.7
# 2022-05-01 00:40:00          0.0          0.0          0.0       287.7
# ...                          ...          ...          ...         ...
# 2022-07-18 23:10:00          0.0          0.0          0.0       288.0
# 2022-07-18 23:20:00          0.0          0.0          0.0       287.0
# 2022-07-18 23:30:00          0.0          0.0          0.0       299.0
# 2022-07-18 23:40:00          0.0          0.0          0.0       309.0
# 2022-07-18 23:50:00          0.0          0.0          0.0       326.0
#
#                      wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-05-01 00:00:00       284.2       279.0       269.3
# 2022-05-01 00:10:00       284.2       279.0       266.3
# 2022-05-01 00:20:00       284.2       279.0       264.3
# 2022-05-01 00:30:00       284.2       279.0       263.3
# 2022-05-01 00:40:00       284.2       279.0       264.3
# ...                         ...         ...         ...
# 2022-07-18 23:10:00       295.0       299.0       306.0
# 2022-07-18 23:20:00       303.0       304.0       308.0
# 2022-07-18 23:30:00       307.0       309.0       310.0
# 2022-07-18 23:40:00       311.0       314.0       312.0
# 2022-07-18 23:50:00       314.0       317.0       313.0
#
# [11376 rows x 16 columns]

# %%
df_forecast=pd.DataFrame(index=df_tt.index, columns=df_tt.columns)
df_forecast
# Out:
#                      swl  inf  sfw ecpc tototf tide_level fw_1018662  \
# ymdhm
# 2022-05-01 00:00:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# ...                  ...  ...  ...  ...    ...        ...        ...
# 2022-07-18 23:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:50:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
#
#                     fw_1018683 fw_1019630 rf_10184100 rf_10184110 rf_10184140  \
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:40:00        NaN        NaN         NaN         NaN         NaN
# ...                        ...        ...         ...         ...         ...
# 2022-07-18 23:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:40:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:50:00        NaN        NaN         NaN         NaN         NaN
#
#                     wl_1018662 wl_1018680 wl_1018683 wl_1019630
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:10:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:20:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:30:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:40:00        NaN        NaN        NaN        NaN
# ...                        ...        ...        ...        ...
# 2022-07-18 23:10:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:20:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:30:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:40:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:50:00        NaN        NaN        NaN        NaN
#
# [11376 rows x 16 columns]

# %%
df_forecast232=get_fc_ys(232,df_train,df_tt,df_forecast)
df_forecast232=df_forecast232.loc['2022-06':,y_cols]
df_forecast232
# Out:
# 100%|██████████| 6912/6912 [00:09<00:00, 742.24it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.881067  277.357497  274.755918  269.417796
# 2022-06-01 00:10:00  280.965182   276.09842  273.344968  267.905346
# 2022-06-01 00:20:00  282.963533  276.668954  273.371601  264.923645
# 2022-06-01 00:30:00  285.735841  277.498578  273.749826  261.724296
# 2022-06-01 00:40:00  286.074258  278.092361  273.938219  258.757841
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.717848  293.855113  297.631806  306.482227
# 2022-07-18 23:20:00  290.402725  302.650977   305.30352   307.89898
# 2022-07-18 23:30:00   295.93029  307.061065  307.808883   310.37599
# 2022-07-18 23:40:00  310.771316  311.819821  312.804292   311.53597
# 2022-07-18 23:50:00  321.814646  316.177708  316.869133  312.211123
#
# [6912 rows x 4 columns]

# %% [markdown]
# ### inf, sfw 변수 제외

# %%
df_train2=df_train.drop(['inf','sfw'], axis=1)
df_tt2=df_tt.drop(['inf','sfw'], axis=1)
df_forecast2=df_forecast.drop(['inf','sfw'], axis=1)

# %%
df_forecast232_1=get_fc_ys(232,df_train2,df_tt2,df_forecast2)
df_forecast232_1=df_forecast232_1.loc['2022-06':,y_cols]
df_forecast232_1
# Out:
# 100%|██████████| 6912/6912 [00:06<00:00, 1047.62it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.786825    277.4177  274.769228   269.50725
# 2022-06-01 00:10:00  280.999447  276.208293  273.530506  267.643645
# 2022-06-01 00:20:00  282.949552  276.616435  273.370686  264.988745
# 2022-06-01 00:30:00  285.414505  277.475162  273.678069  261.556142
# 2022-06-01 00:40:00  286.147097  278.020174  273.932783  258.834942
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.636036    293.7353  297.690609  306.397955
# 2022-07-18 23:20:00  290.227495  302.530986  305.091021  308.171015
# 2022-07-18 23:30:00  295.900694  307.236131  307.898054  310.212295
# 2022-07-18 23:40:00   310.76332  311.737974  312.767172  311.396866
# 2022-07-18 23:50:00  321.905665  316.311362  316.998116  312.409982
#
# [6912 rows x 4 columns]

# %%
df_forecast232_1.to_csv('VAR_MinMax.csv')

# %% [markdown]
# ## Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train = df_log.loc[:'2022-05-31 23:50:00',list(x_cols)]
X_test = df_log.loc['2022-06-01 00:00:00':,list(x_cols)]
Y = df.loc[:,y_cols]
# scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_scaled = np.concatenate([X_train_scaled,X_test_scaled])

df_s = pd.DataFrame(X_scaled,columns=list(x_cols),index=df.index)
df_s.shape
# Out:
# (276336, 12)

# %%
df_scaled=pd.concat([df_s,df[y_cols]], axis=1)
df_train=df_scaled.loc[:'2022-05']
df_tt=df_scaled.loc['2022':]
df_tt
# Out:
#                           swl       inf       sfw      ecpc    tototf  \
# ymdhm
# 2022-05-01 00:00:00  0.798947  0.624999  0.023665  0.298342 -0.765563
# 2022-05-01 00:10:00  0.798947 -0.576113  0.023665  0.298342 -0.764612
# 2022-05-01 00:20:00  0.798947 -0.576825  0.023665  0.298342 -0.766832
# 2022-05-01 00:30:00  0.798947 -0.576444  0.023665  0.298342 -0.765642
# 2022-05-01 00:40:00  0.736122 -0.915875 -0.013134  0.327123 -0.765087
# ...                       ...       ...       ...       ...       ...
# 2022-07-18 23:10:00 -0.242184 -0.256035 -0.600961  0.710149 -0.039717
# 2022-07-18 23:20:00 -0.242184 -0.253304 -0.600961  0.710149 -0.035031
# 2022-07-18 23:30:00 -0.242184 -0.255724 -0.600961  0.710149 -0.039182
# 2022-07-18 23:40:00 -0.242184 -0.256258 -0.600961  0.710149 -0.040099
# 2022-07-18 23:50:00 -0.242184 -0.258414 -0.600961  0.710149 -0.043811
#
#                      tide_level  fw_1018662  fw_1018683  fw_1019630  \
# ymdhm
# 2022-05-01 00:00:00   -2.502480   -0.313766   -0.467720   -0.583782
# 2022-05-01 00:10:00   -2.836381   -0.278241   -0.310953   -0.714150
# 2022-05-01 00:20:00   -3.217806   -0.313766   -0.219847   -0.808792
# 2022-05-01 00:30:00   -3.590842   -0.351233   -0.147631   -0.858833
# 2022-05-01 00:40:00   -3.590842   -0.433090   -0.109935   -0.808792
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00    0.903898   -0.433090   -1.006476    0.459190
# 2022-07-18 23:20:00    0.848615   -0.478221   -1.351719    0.499546
# 2022-07-18 23:30:00    0.794353   -0.070669   -1.530230    0.538919
# 2022-07-18 23:40:00    0.737937    0.149336   -1.800224    0.577359
# 2022-07-18 23:50:00    0.682713    0.420286   -1.840932    0.596254
#
#                      rf_10184100  rf_10184110  rf_10184140  wl_1018662  \
# ymdhm
# 2022-05-01 00:00:00    -0.128373    -0.134619    -0.129634       290.7
# 2022-05-01 00:10:00    -0.128373    -0.134619    -0.129634       291.7
# 2022-05-01 00:20:00    -0.128373    -0.134619    -0.129634       290.7
# 2022-05-01 00:30:00    -0.128373    -0.134619    -0.129634       289.7
# 2022-05-01 00:40:00    -0.128373    -0.134619    -0.129634       287.7
# ...                          ...          ...          ...         ...
# 2022-07-18 23:10:00    -0.128373    -0.134619    -0.129634       288.0
# 2022-07-18 23:20:00    -0.128373    -0.134619    -0.129634       287.0
# 2022-07-18 23:30:00    -0.128373    -0.134619    -0.129634       299.0
# 2022-07-18 23:40:00    -0.128373    -0.134619    -0.129634       309.0
# 2022-07-18 23:50:00    -0.128373    -0.134619    -0.129634       326.0
#
#                      wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-05-01 00:00:00       284.2       279.0       269.3
# 2022-05-01 00:10:00       284.2       279.0       266.3
# 2022-05-01 00:20:00       284.2       279.0       264.3
# 2022-05-01 00:30:00       284.2       279.0       263.3
# 2022-05-01 00:40:00       284.2       279.0       264.3
# ...                         ...         ...         ...
# 2022-07-18 23:10:00       295.0       299.0       306.0
# 2022-07-18 23:20:00       303.0       304.0       308.0
# 2022-07-18 23:30:00       307.0       309.0       310.0
# 2022-07-18 23:40:00       311.0       314.0       312.0
# 2022-07-18 23:50:00       314.0       317.0       313.0
#
# [11376 rows x 16 columns]

# %%
df_forecast=pd.DataFrame(index=df_tt.index, columns=df_tt.columns)
df_forecast
# Out:
#                      swl  inf  sfw ecpc tototf tide_level fw_1018662  \
# ymdhm
# 2022-05-01 00:00:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# ...                  ...  ...  ...  ...    ...        ...        ...
# 2022-07-18 23:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:50:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
#
#                     fw_1018683 fw_1019630 rf_10184100 rf_10184110 rf_10184140  \
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:40:00        NaN        NaN         NaN         NaN         NaN
# ...                        ...        ...         ...         ...         ...
# 2022-07-18 23:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:40:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:50:00        NaN        NaN         NaN         NaN         NaN
#
#                     wl_1018662 wl_1018680 wl_1018683 wl_1019630
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:10:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:20:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:30:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:40:00        NaN        NaN        NaN        NaN
# ...                        ...        ...        ...        ...
# 2022-07-18 23:10:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:20:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:30:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:40:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:50:00        NaN        NaN        NaN        NaN
#
# [11376 rows x 16 columns]

# %%
df_forecast232=get_fc_ys(232,df_train,df_tt,df_forecast)
df_forecast232=df_forecast232.loc['2022-06':,y_cols]
df_forecast232
# Out:
# 100%|██████████| 6912/6912 [00:09<00:00, 766.17it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.881067  277.357497  274.755918  269.417796
# 2022-06-01 00:10:00  280.965182   276.09842  273.344968  267.905346
# 2022-06-01 00:20:00  282.963533  276.668954  273.371601  264.923645
# 2022-06-01 00:30:00  285.735841  277.498578  273.749826  261.724296
# 2022-06-01 00:40:00  286.074258  278.092361  273.938219  258.757841
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.717848  293.855113  297.631806  306.482227
# 2022-07-18 23:20:00  290.402725  302.650977   305.30352   307.89898
# 2022-07-18 23:30:00   295.93029  307.061065  307.808883   310.37599
# 2022-07-18 23:40:00  310.771316  311.819821  312.804292   311.53597
# 2022-07-18 23:50:00  321.814646  316.177708  316.869133  312.211123
#
# [6912 rows x 4 columns]

# %% [markdown]
# ### inf, sfw 변수 제외

# %%
df_train2=df_train.drop(['inf','sfw'], axis=1)
df_tt2=df_tt.drop(['inf','sfw'], axis=1)
df_forecast2=df_forecast.drop(['inf','sfw'], axis=1)

# %%
df_forecast232_2=get_fc_ys(232,df_train2,df_tt2,df_forecast2)
df_forecast232_2=df_forecast232_2.loc['2022-06':,y_cols]
df_forecast232_2
# Out:
# 100%|██████████| 6912/6912 [00:06<00:00, 1021.20it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.786825    277.4177  274.769228   269.50725
# 2022-06-01 00:10:00  280.999447  276.208293  273.530506  267.643645
# 2022-06-01 00:20:00  282.949552  276.616435  273.370686  264.988745
# 2022-06-01 00:30:00  285.414505  277.475162  273.678069  261.556142
# 2022-06-01 00:40:00  286.147097  278.020174  273.932783  258.834942
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.636036    293.7353  297.690609  306.397955
# 2022-07-18 23:20:00  290.227495  302.530986  305.091021  308.171015
# 2022-07-18 23:30:00  295.900694  307.236131  307.898054  310.212295
# 2022-07-18 23:40:00   310.76332  311.737974  312.767172  311.396866
# 2022-07-18 23:50:00  321.905665  316.311362  316.998116  312.409982
#
# [6912 rows x 4 columns]

# %%
df_forecast232_2.to_csv('VAR_Standard.csv')

# %% [markdown]
# ## Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler

# %%
X_train = df_log.loc[:'2022-05-31 23:50:00',list(x_cols)]
X_test = df_log.loc['2022-06-01 00:00:00':,list(x_cols)]
Y = df.loc[:,y_cols]
# scaling
scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_scaled = np.concatenate([X_train_scaled,X_test_scaled])

df_r = pd.DataFrame(X_scaled,columns=list(x_cols),index=df.index)
df_r.shape
# Out:
# (276336, 12)

# %%
df_scaled=pd.concat([df_r,df[y_cols]], axis=1)
df_train=df_scaled.loc[:'2022-05']
df_tt=df_scaled.loc['2022':]
df_tt
# Out:
#                           swl       inf       sfw      ecpc    tototf  \
# ymdhm
# 2022-05-01 00:00:00  0.413493  1.084864  0.045489 -0.036873 -0.254051
# 2022-05-01 00:10:00  0.413493 -0.353182  0.045489 -0.036873 -0.253326
# 2022-05-01 00:20:00  0.413493 -0.354035  0.045489 -0.036873 -0.255019
# 2022-05-01 00:30:00  0.413493 -0.353578  0.045489 -0.036873 -0.254112
# 2022-05-01 00:40:00  0.368897 -0.759967  0.023444 -0.018779 -0.253689
# ...                       ...       ...       ...       ...       ...
# 2022-07-18 23:10:00 -0.325560  0.030035 -0.328714  0.222025  0.299327
# 2022-07-18 23:20:00 -0.325560  0.033305 -0.328714  0.222025  0.302900
# 2022-07-18 23:30:00 -0.325560  0.030407 -0.328714  0.222025  0.299735
# 2022-07-18 23:40:00 -0.325560  0.029769 -0.328714  0.222025  0.299036
# 2022-07-18 23:50:00 -0.325560  0.027187 -0.328714  0.222025  0.296206
#
#                      tide_level  fw_1018662  fw_1018683  fw_1019630  \
# ymdhm
# 2022-05-01 00:00:00   -1.770717   -0.420003   -0.762903   -0.431460
# 2022-05-01 00:10:00   -1.990179   -0.386385   -0.441639   -0.530158
# 2022-05-01 00:20:00   -2.240876   -0.420003   -0.254934   -0.601808
# 2022-05-01 00:30:00   -2.486061   -0.455459   -0.106943   -0.639692
# 2022-05-01 00:40:00   -2.486061   -0.532921   -0.029691   -0.601808
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00    0.468182   -0.532921   -1.866979    0.358142
# 2022-07-18 23:20:00    0.431846   -0.575630   -2.574487    0.388694
# 2022-07-18 23:30:00    0.396181   -0.189954   -2.940312    0.418501
# 2022-07-18 23:40:00    0.359101    0.018241   -3.493612    0.447604
# 2022-07-18 23:50:00    0.322804    0.274647   -3.577035    0.461908
#
#                      rf_10184100  rf_10184110  rf_10184140  wl_1018662  \
# ymdhm
# 2022-05-01 00:00:00          0.0          0.0          0.0       290.7
# 2022-05-01 00:10:00          0.0          0.0          0.0       291.7
# 2022-05-01 00:20:00          0.0          0.0          0.0       290.7
# 2022-05-01 00:30:00          0.0          0.0          0.0       289.7
# 2022-05-01 00:40:00          0.0          0.0          0.0       287.7
# ...                          ...          ...          ...         ...
# 2022-07-18 23:10:00          0.0          0.0          0.0       288.0
# 2022-07-18 23:20:00          0.0          0.0          0.0       287.0
# 2022-07-18 23:30:00          0.0          0.0          0.0       299.0
# 2022-07-18 23:40:00          0.0          0.0          0.0       309.0
# 2022-07-18 23:50:00          0.0          0.0          0.0       326.0
#
#                      wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-05-01 00:00:00       284.2       279.0       269.3
# 2022-05-01 00:10:00       284.2       279.0       266.3
# 2022-05-01 00:20:00       284.2       279.0       264.3
# 2022-05-01 00:30:00       284.2       279.0       263.3
# 2022-05-01 00:40:00       284.2       279.0       264.3
# ...                         ...         ...         ...
# 2022-07-18 23:10:00       295.0       299.0       306.0
# 2022-07-18 23:20:00       303.0       304.0       308.0
# 2022-07-18 23:30:00       307.0       309.0       310.0
# 2022-07-18 23:40:00       311.0       314.0       312.0
# 2022-07-18 23:50:00       314.0       317.0       313.0
#
# [11376 rows x 16 columns]

# %%
df_forecast=pd.DataFrame(index=df_tt.index, columns=df_tt.columns)
df_forecast
# Out:
#                      swl  inf  sfw ecpc tototf tide_level fw_1018662  \
# ymdhm
# 2022-05-01 00:00:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-05-01 00:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# ...                  ...  ...  ...  ...    ...        ...        ...
# 2022-07-18 23:10:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:20:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:30:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:40:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
# 2022-07-18 23:50:00  NaN  NaN  NaN  NaN    NaN        NaN        NaN
#
#                     fw_1018683 fw_1019630 rf_10184100 rf_10184110 rf_10184140  \
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-05-01 00:40:00        NaN        NaN         NaN         NaN         NaN
# ...                        ...        ...         ...         ...         ...
# 2022-07-18 23:10:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:20:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:30:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:40:00        NaN        NaN         NaN         NaN         NaN
# 2022-07-18 23:50:00        NaN        NaN         NaN         NaN         NaN
#
#                     wl_1018662 wl_1018680 wl_1018683 wl_1019630
# ymdhm
# 2022-05-01 00:00:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:10:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:20:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:30:00        NaN        NaN        NaN        NaN
# 2022-05-01 00:40:00        NaN        NaN        NaN        NaN
# ...                        ...        ...        ...        ...
# 2022-07-18 23:10:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:20:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:30:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:40:00        NaN        NaN        NaN        NaN
# 2022-07-18 23:50:00        NaN        NaN        NaN        NaN
#
# [11376 rows x 16 columns]

# %%
df_forecast232=get_fc_ys(232,df_train,df_tt,df_forecast)
df_forecast232=df_forecast232.loc['2022-06':,y_cols]
df_forecast232
# Out:
# 100%|██████████| 6912/6912 [00:08<00:00, 774.78it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.881067  277.357497  274.755918  269.417796
# 2022-06-01 00:10:00  280.965182   276.09842  273.344968  267.905346
# 2022-06-01 00:20:00  282.963533  276.668954  273.371601  264.923645
# 2022-06-01 00:30:00  285.735841  277.498578  273.749826  261.724296
# 2022-06-01 00:40:00  286.074258  278.092361  273.938219  258.757841
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.717848  293.855113  297.631806  306.482227
# 2022-07-18 23:20:00  290.402725  302.650977   305.30352   307.89898
# 2022-07-18 23:30:00   295.93029  307.061065  307.808883   310.37599
# 2022-07-18 23:40:00  310.771316  311.819821  312.804292   311.53597
# 2022-07-18 23:50:00  321.814646  316.177708  316.869133  312.211123
#
# [6912 rows x 4 columns]

# %% [markdown]
# ### inf, sfw 변수 제외

# %%
df_train2=df_train.drop(['inf','sfw'], axis=1)
df_tt2=df_tt.drop(['inf','sfw'], axis=1)
df_forecast2=df_forecast.drop(['inf','sfw'], axis=1)

# %%
df_forecast232_3=get_fc_ys(232,df_train2,df_tt2,df_forecast2)
df_forecast232_3=df_forecast232_3.loc['2022-06':,y_cols]
df_forecast232_3
# Out:
# 100%|██████████| 6912/6912 [00:06<00:00, 989.36it/s]
#                      wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00:00  279.786825    277.4177  274.769228   269.50725
# 2022-06-01 00:10:00  280.999447  276.208293  273.530506  267.643645
# 2022-06-01 00:20:00  282.949552  276.616435  273.370686  264.988745
# 2022-06-01 00:30:00  285.414505  277.475162  273.678069  261.556142
# 2022-06-01 00:40:00  286.147097  278.020174  273.932783  258.834942
# ...                         ...         ...         ...         ...
# 2022-07-18 23:10:00  288.636036    293.7353  297.690609  306.397955
# 2022-07-18 23:20:00  290.227495  302.530986  305.091021  308.171015
# 2022-07-18 23:30:00  295.900694  307.236131  307.898054  310.212295
# 2022-07-18 23:40:00   310.76332  311.737974  312.767172  311.396866
# 2022-07-18 23:50:00  321.905665  316.311362  316.998116  312.409982
#
# [6912 rows x 4 columns]

# %%
df_forecast232_3.to_csv('VAR_Robust.csv')

# %% [markdown]
# # Ensemble

# %%
df1 = pd.read_csv('VAR_log.csv',index_col=0)
df2 = pd.read_csv('VAR_MinMax.csv',index_col=0)
df3 = pd.read_csv('VAR_Standard.csv',index_col=0)
df4 = pd.read_csv('VAR_Robust.csv',index_col=0)

# %%
val = (df1.values+df2.values+df3.values+df4.values)/4

# %%
val
# Out:
# array([[279.78682549, 277.41770016, 274.76922806, 269.50724953],
#        [280.9994474 , 276.20829309, 273.53050632, 267.64364494],
#        [282.94955188, 276.61643539, 273.37068563, 264.98874494],
#        ...,
#        [295.900694  , 307.23613119, 307.89805401, 310.21229469],
#        [310.76331983, 311.73797398, 312.76717206, 311.39686556],
#        [321.90566541, 316.31136219, 316.99811645, 312.40998228]])

# %%
sub = pd.read_csv('sample_submission.csv',index_col=0)

# %%
final_sub = pd.DataFrame(val,index=sub.index,columns=sub.columns)
final_sub
# Out:
#                   wl_1018662  wl_1018680  wl_1018683  wl_1019630
# ymdhm
# 2022-06-01 00:00  279.786825  277.417700  274.769228  269.507250
# 2022-06-01 00:10  280.999447  276.208293  273.530506  267.643645
# 2022-06-01 00:20  282.949552  276.616435  273.370686  264.988745
# 2022-06-01 00:30  285.414505  277.475162  273.678069  261.556142
# 2022-06-01 00:40  286.147097  278.020174  273.932783  258.834942
# ...                      ...         ...         ...         ...
# 2022-07-18 23:10  288.636036  293.735300  297.690609  306.397955
# 2022-07-18 23:20  290.227495  302.530986  305.091021  308.171015
# 2022-07-18 23:30  295.900694  307.236131  307.898054  310.212295
# 2022-07-18 23:40  310.763320  311.737974  312.767172  311.396866
# 2022-07-18 23:50  321.905665  316.311362  316.998116  312.409982
#
# [6912 rows x 4 columns]

# %%
final_sub.to_csv('final_sub.csv')
